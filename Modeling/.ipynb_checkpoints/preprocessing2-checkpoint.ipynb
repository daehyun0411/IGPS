# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings


plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = (16,8)
plt.rc('font', family='Malgun Gothic')
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv("C:/Users/keogu/Desktop/IGPS/Data/평균이용량_대여_반납.csv")
seoul = pd.read_csv("C:/Users/keogu/Desktop/IGPS/Data/서울시_데이터종합(연면적sum,거주인구).csv", encoding = 'cp949')

# %% [markdown]
# # 서울시 평균이용량

# %%
df.head()
# Out:
#    대여소번호    총대여건수    총반납건수      총이용량  19년도총이용량  20년도총이용량   유지기간     일별평균이용량  \
# 0  101.0  14919.0  14714.0   29633.0   17607.0   12026.0  730.0   40.593151
# 1  102.0  59082.0  54010.0  113092.0   67430.0   45662.0  730.0  154.920548
# 2  103.0  40655.0  38358.0   79013.0   46153.0   32860.0  730.0  108.236986
# 3  104.0  34652.0  30358.0   65010.0   39840.0   25170.0  730.0   89.054795
# 4  105.0  20565.0  18317.0   38882.0   20860.0   18022.0  730.0   53.263014
#
#    일별대여평균이용량  일별반납평균이용량
# 0  20.436986  20.156164
# 1  80.934247  73.986301
# 2  55.691781  52.545205
# 3  47.468493  41.586301
# 4  28.171233  25.091781

# %%
df.describe()
# Out:
#              대여소번호          총대여건수          총반납건수           총이용량  \
# count  1511.000000    1511.000000    1511.000000    1511.000000
# mean   1300.999338   20075.628061   18305.033091   38380.661152
# std     815.275728   17581.136413   16131.538867   33501.494135
# min     101.000000     179.000000     161.000000     340.000000
# 25%     583.500000    9347.500000    7946.500000   17336.500000
# 50%    1229.000000   16168.000000   14644.000000   30573.000000
# 75%    1959.500000   25921.500000   24202.500000   50333.000000
# max    3543.000000  317792.000000  201692.000000  505278.000000
#
#             19년도총이용량       20년도총이용량         유지기간      일별평균이용량    일별대여평균이용량  \
# count    1511.000000    1511.000000  1511.000000  1511.000000  1511.000000
# mean    19327.982131   19052.679021   716.252151    65.408182    34.127892
# std     17100.730083   17137.696889    88.329564   159.577072    82.369919
# min         9.000000     266.000000    19.000000     0.950685     0.583562
# 25%      8106.000000    8643.000000   730.000000    24.070548    12.857534
# 50%     15138.000000   15155.000000   730.000000    42.406849    22.436986
# 75%     25806.500000   24900.000000   730.000000    70.402740    36.439726
# max    218286.000000  286992.000000   914.000000  3648.250000  1917.150000
#
#          일별반납평균이용량
# count  1511.000000
# mean     31.280290
# std      77.720766
# min       0.286301
# 25%      11.009589
# 50%      20.246575
# 75%      33.984932
# max    1731.100000

# %% [markdown]
# ## 이상치 제거

# %%
df.set_index(['대여소번호'], inplace=True)

# %%
# 이상한 값들 존재??
df.sort_values(by=['일별대여평균이용량'], ascending=False)
# Out:
#            총대여건수     총반납건수      총이용량  19년도총이용량  20년도총이용량   유지기간      일별평균이용량  \
# 대여소번호
# 1124.0   38343.0   34622.0   72965.0   35963.0   37002.0   20.0  3648.250000
# 905.0    25550.0   27726.0   53276.0   25616.0   27660.0   19.0  2804.000000
# 152.0   114259.0  122056.0  236315.0  116086.0  120229.0   98.0  2411.377551
# 583.0   317792.0  187486.0  505278.0  218286.0  286992.0  914.0  1719.118865
# 2348.0   25729.0   24968.0   50697.0   25849.0   24848.0   37.0  1370.189189
# ...          ...       ...       ...       ...       ...    ...          ...
# 2286.0    1096.0     230.0    1326.0     710.0     616.0  730.0     1.816438
# 2395.0     866.0     554.0    1420.0     943.0     477.0  730.0     1.945205
# 2288.0     682.0     396.0    1078.0     650.0     428.0  730.0     1.476712
# 2287.0     485.0     209.0     694.0     388.0     306.0  730.0     0.950685
# 2391.0     426.0     373.0     799.0     457.0     342.0  730.0     1.094521
#
#           일별대여평균이용량    일별반납평균이용량
# 대여소번호
# 1124.0  1917.150000  1731.100000
# 905.0   1344.736842  1459.263158
# 152.0   1165.908163  1245.469388
# 583.0   1081.230971   637.887895
# 2348.0   695.378378   674.810811
# ...             ...          ...
# 2286.0     1.501370     0.315068
# 2395.0     1.186301     0.758904
# 2288.0     0.934247     0.542466
# 2287.0     0.664384     0.286301
# 2391.0     0.583562     0.510959
#
# [1511 rows x 9 columns]

# %%
sns.boxplot(x = '일별대여평균이용량', data=df)
plt.show()

# %%
def get_outlier(df=None, column=None, weight=1.5):
    quantile_25 = np.percentile(df[column].values, 25)
    quantile_75 = np.percentile(df[column].values, 75)

    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*weight
  
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
  
    outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
    return outlier_idx

# %%
# 너무 많다..?
outlier_index = get_outlier(df=df, column='일별대여평균이용량', weight=1.5)
len(outlier_index)
# Out:
# 76

# %%
len(df[(df['유지기간'] < 365)|(df['유지기간'] > 730)])
# Out:
# 29

# %%
index = df[(df['유지기간'] < 365)|(df['유지기간'] > 730)].index

# %%
df.drop(index, axis=0, inplace=True)
df
# Out:
#           총대여건수    총반납건수      총이용량  19년도총이용량  20년도총이용량   유지기간     일별평균이용량  \
# 대여소번호
# 101.0   14919.0  14714.0   29633.0   17607.0   12026.0  730.0   40.593151
# 102.0   59082.0  54010.0  113092.0   67430.0   45662.0  730.0  154.920548
# 103.0   40655.0  38358.0   79013.0   46153.0   32860.0  730.0  108.236986
# 104.0   34652.0  30358.0   65010.0   39840.0   25170.0  730.0   89.054795
# 105.0   20565.0  18317.0   38882.0   20860.0   18022.0  730.0   53.263014
# ...         ...      ...       ...       ...       ...    ...         ...
# 3538.0  11992.0   9568.0   21560.0    9306.0   12254.0  730.0   29.534247
# 3539.0   2457.0   2353.0    4810.0    1845.0    2965.0  730.0    6.589041
# 3541.0  56642.0  42544.0   99186.0   54554.0   44632.0  730.0  135.871233
# 3542.0  25905.0  20227.0   46132.0   26719.0   19413.0  730.0   63.194521
# 3543.0   2902.0   2250.0    5152.0       9.0    5143.0  381.0   13.522310
#
#         일별대여평균이용량  일별반납평균이용량
# 대여소번호
# 101.0   20.436986  20.156164
# 102.0   80.934247  73.986301
# 103.0   55.691781  52.545205
# 104.0   47.468493  41.586301
# 105.0   28.171233  25.091781
# ...           ...        ...
# 3538.0  16.427397  13.106849
# 3539.0   3.365753   3.223288
# 3541.0  77.591781  58.279452
# 3542.0  35.486301  27.708219
# 3543.0   7.616798   5.905512
#
# [1482 rows x 9 columns]

# %% [markdown]
# # 서울시 지리정보

# %%
seoul.head()
# Out:
#    Unnamed: 0   대여소번호      일별평균이용량  교육시설_sum  근린생활시설_sum  문화시설_sum  숙박시설_sum  \
# 0           0   502.0   534.895890       0.0        0.00      0.00       0.0
# 1           1   207.0   489.505479       0.0      161.73      0.00       0.0
# 2           2   583.0   346.080822       0.0     1932.80      0.00       0.0
# 3           3  3533.0   239.726027       0.0     5763.49   4697.48       0.0
# 4           4   152.0  2411.377551       0.0      954.10      0.00       0.0
#
#    업무시설_sum  의료시설_sum   주거시설_sum  판매시설_sum  공원_distance  대학교_distance  \
# 0    906.60       0.0  137575.50      0.00   137.510195   1430.131460
# 1      0.00       0.0   62279.03      0.00   209.972349   2254.225628
# 2   4184.18       0.0   59977.04      0.00   233.562697   1087.731522
# 3      0.00       0.0    1152.39  90429.46   161.743567    639.201940
# 4      0.00       0.0   30110.49      0.00    99.606355   2534.786324
#
#    지하철_distance  버스_distance  경사도_mean   거주인구        도로길이
# 0     55.873032    59.208388  0.500000  24085  714.440640
# 1     72.001620    31.257419  1.000000  15710  356.416445
# 2    197.716089    47.019980  0.571429  30156  520.130672
# 3    175.855911    42.881442  0.000000  43626  549.726995
# 4    899.273615    53.992085  0.500000  21319  739.718938

# %%
seoul.drop(['Unnamed: 0','일별평균이용량'], axis=1,inplace=True)
seoul.set_index(['대여소번호'], inplace=True)

# %%
seoul.drop(index, axis=0, inplace=True)

# %%
seoul
# Out:
#         교육시설_sum  근린생활시설_sum  문화시설_sum  숙박시설_sum  업무시설_sum  의료시설_sum  \
# 대여소번호
# 502.0       0.00        0.00      0.00       0.0    906.60       0.0
# 207.0       0.00      161.73      0.00       0.0      0.00       0.0
# 3533.0      0.00     5763.49   4697.48       0.0      0.00       0.0
# 1210.0      0.00        0.00      0.00       0.0      0.00       0.0
# 1308.0  39658.62    27219.63    552.09       0.0   3227.37       0.0
# ...          ...         ...       ...       ...       ...       ...
# 664.0   61560.86        0.00   7622.29       0.0      0.00       0.0
# 2287.0      0.00     3830.38      0.00       0.0      0.00       0.0
# 2391.0      0.00        0.00      0.00       0.0      0.00       0.0
# 465.0       0.00     6864.08      0.00       0.0      0.00       0.0
# 3543.0  73957.07        0.00   4825.13       0.0      0.00       0.0
#
#          주거시설_sum  판매시설_sum  공원_distance  대학교_distance  지하철_distance  \
# 대여소번호
# 502.0   137575.50      0.00   137.510195   1430.131460     55.873032
# 207.0    62279.03      0.00   209.972349   2254.225628     72.001620
# 3533.0    1152.39  90429.46   161.743567    639.201940    175.855911
# 1210.0       0.00      0.00   324.671476   2761.514679    145.087355
# 1308.0    8097.88      0.00   332.366534    749.646476    408.450803
# ...           ...       ...          ...           ...           ...
# 664.0        0.00      0.00   332.212513     88.481654    592.515746
# 2287.0    4749.01      0.00   187.100314   5396.477786   3469.661173
# 2391.0    3456.00      0.00   366.727904   4119.802431   1206.457463
# 465.0      527.37      0.00   377.608155    301.960064   1245.792726
# 3543.0    3332.92      0.00   361.589287     69.821617    373.301440
#
#         버스_distance  경사도_mean   거주인구         도로길이
# 대여소번호
# 502.0     59.208388  0.500000  24085   714.440640
# 207.0     31.257419  1.000000  15710   356.416445
# 3533.0    42.881442  0.000000  43626   549.726995
# 1210.0    70.406036  0.333333  24052   348.694407
# 1308.0    12.103377  1.250000  41364  1258.678353
# ...             ...       ...    ...          ...
# 664.0    370.864704  2.000000   8727     0.000000
# 2287.0   272.330166  7.444444   8164   749.655227
# 2391.0   144.812218  4.500000  14769   345.607938
# 465.0    167.833245  6.250000   1224   424.978106
# 3543.0   209.554916  1.000000  12977   127.856886
#
# [1482 rows x 15 columns]

# %% [markdown]
# ## 토지이용혼합도

# %%
from numpy import log as ln

# %%
seoul['sum'] =  seoul.iloc[:,0] + seoul.iloc[:,1] + seoul.iloc[:,2] + seoul.iloc[:,3] + seoul.iloc[:,4] + seoul.iloc[:,5] + seoul.iloc[:,6] + seoul.iloc[:,7]

# %%
for i in range(8):
    seoul.iloc[:,i] = -1 * (seoul.iloc[:,i]/seoul['sum']) * ln(seoul.iloc[:,i]/seoul['sum'])
seoul.fillna(0, inplace=True)

# %%
seoul
# Out:
#         교육시설_sum  근린생활시설_sum  문화시설_sum  숙박시설_sum  업무시설_sum  의료시설_sum  \
# 대여소번호
# 502.0   0.000000    0.000000  0.000000       0.0  0.032922       0.0
# 207.0   0.000000    0.015427  0.000000       0.0  0.000000       0.0
# 3533.0  0.000000    0.162318  0.141711       0.0  0.000000       0.0
# 1210.0  0.000000    0.000000  0.000000       0.0  0.000000       0.0
# 1308.0  0.345467    0.367192  0.034773       0.0  0.130917       0.0
# ...          ...         ...       ...       ...       ...       ...
# 664.0   0.103870    0.000000  0.243012       0.0  0.000000       0.0
# 2287.0  0.000000    0.360027  0.000000       0.0  0.000000       0.0
# 2391.0  0.000000    0.000000  0.000000       0.0  0.000000       0.0
# 465.0   0.000000    0.068741  0.000000       0.0  0.000000       0.0
# 3543.0  0.094242    0.000000  0.166544       0.0  0.000000       0.0
#
#         주거시설_sum  판매시설_sum  공원_distance  대학교_distance  지하철_distance  \
# 대여소번호
# 502.0   0.006525  0.000000   137.510195   1430.131460     55.873032
# 207.0   0.002587  0.000000   209.972349   2254.225628     72.001620
# 3533.0  0.050634  0.107072   161.743567    639.201940    175.855911
# 1210.0  0.000000  0.000000   324.671476   2761.514679    145.087355
# 1308.0  0.233896  0.000000   332.366534    749.646476    408.450803
# ...          ...       ...          ...           ...           ...
# 664.0   0.000000  0.000000   332.212513     88.481654    592.515746
# 2287.0  0.327377  0.000000   187.100314   5396.477786   3469.661173
# 2391.0 -0.000000  0.000000   366.727904   4119.802431   1206.457463
# 465.0   0.188373  0.000000   377.608155    301.960064   1245.792726
# 3543.0  0.130056  0.000000   361.589287     69.821617    373.301440
#
#         버스_distance  경사도_mean   거주인구         도로길이        sum
# 대여소번호
# 502.0     59.208388  0.500000  24085   714.440640  138482.10
# 207.0     31.257419  1.000000  15710   356.416445   62440.76
# 3533.0    42.881442  0.000000  43626   549.726995  102042.82
# 1210.0    70.406036  0.333333  24052   348.694407       0.00
# 1308.0    12.103377  1.250000  41364  1258.678353   78755.59
# ...             ...       ...    ...          ...        ...
# 664.0    370.864704  2.000000   8727     0.000000   69183.15
# 2287.0   272.330166  7.444444   8164   749.655227    8579.39
# 2391.0   144.812218  4.500000  14769   345.607938    3456.00
# 465.0    167.833245  6.250000   1224   424.978106    7391.45
# 3543.0   209.554916  1.000000  12977   127.856886   82115.12
#
# [1482 rows x 16 columns]

# %%
seoul['LUM'] = (seoul.iloc[:,0] + seoul.iloc[:,1] + seoul.iloc[:,2] + seoul.iloc[:,3] + seoul.iloc[:,4] + seoul.iloc[:,5] + seoul.iloc[:,6] + seoul.iloc[:,7])/ln(8)

# %%
seoul = seoul.iloc[:,8:]

# %% [markdown]
# # 최종데이터

# %%
total = seoul.join(df[['일별대여평균이용량']], how='left')

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1482 entries, 502.0 to 3543.0
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   공원_distance   1482 non-null   float64
#  1   대학교_distance  1482 non-null   float64
#  2   지하철_distance  1482 non-null   float64
#  3   버스_distance   1482 non-null   float64
#  4   경사도_mean      1482 non-null   float64
#  5   거주인구          1482 non-null   int64
#  6   도로길이          1482 non-null   float64
#  7   sum           1482 non-null   float64
#  8   LUM           1482 non-null   float64
#  9   일별대여평균이용량     1482 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 159.6 KB

# %%
total.to_csv("C:/Users/keogu/Desktop/IGPS/Data/서울시_데이터종합_수정2.csv")

# %%
total
# Out:
#         공원_distance  대학교_distance  지하철_distance  버스_distance  경사도_mean   거주인구  \
# 대여소번호
# 502.0    137.510195   1430.131460     55.873032    59.208388  0.500000  24085
# 207.0    209.972349   2254.225628     72.001620    31.257419  1.000000  15710
# 3533.0   161.743567    639.201940    175.855911    42.881442  0.000000  43626
# 1210.0   324.671476   2761.514679    145.087355    70.406036  0.333333  24052
# 1308.0   332.366534    749.646476    408.450803    12.103377  1.250000  41364
# ...             ...           ...           ...          ...       ...    ...
# 664.0    332.212513     88.481654    592.515746   370.864704  2.000000   8727
# 2287.0   187.100314   5396.477786   3469.661173   272.330166  7.444444   8164
# 2391.0   366.727904   4119.802431   1206.457463   144.812218  4.500000  14769
# 465.0    377.608155    301.960064   1245.792726   167.833245  6.250000   1224
# 3543.0   361.589287     69.821617    373.301440   209.554916  1.000000  12977
#
#                도로길이        sum       LUM   일별대여평균이용량
# 대여소번호
# 502.0    714.440640  138482.10  0.018970  258.605479
# 207.0    356.416445   62440.76  0.008663  250.934247
# 3533.0   549.726995  102042.82  0.222047  135.227397
# 1210.0   348.694407       0.00  0.000000  133.017808
# 1308.0  1258.678353   78755.59  0.534877  117.180822
# ...             ...        ...       ...         ...
# 664.0      0.000000   69183.15  0.166815    7.950860
# 2287.0   749.655227    8579.39  0.330571    0.664384
# 2391.0   345.607938    3456.00  0.000000    0.583562
# 465.0    424.978106    7391.45  0.123646    3.122850
# 3543.0   127.856886   82115.12  0.187955    7.616798
#
# [1482 rows x 10 columns]

# %% [markdown]
# # 시각화

# %%
plt.figure(figsize=(16,24))
sns.heatmap(total.corr(), annot=True)

# %%
plt.figure(figsize=(16,24)) # 먼저 창을 만들고
n=1
for feature in total.columns:
    ax = plt.subplot(3,4,n) # for문을 돌면서 Axes를 추가
    plt.title('%s의 분포' %feature, fontsize=15)
    sns.distplot(total[feature], kde =False)
    plt.xticks(rotation=90)
    n+=1
plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()
