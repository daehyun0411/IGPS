# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings


plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["figure.figsize"] = (16,8)
plt.rc('font', family='Malgun Gothic')
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 인천시 데이터

# %%
pb = pd.read_csv("C:/Users/keogu/Desktop/IGPS/Data/쏠림현상해결.csv", encoding = 'cp949')

# %%
pb
# Out:
#     field_1  field_1_1     grid  rank_x   fid ADM_DR_NM  rank_y
# 0       0.0     2388.0  그리드3211     1.0  3211      주안4동     1.0
# 1       1.0     2068.0  그리드2783     2.0  2783      주안1동     2.0
# 2       2.0      608.0  그리드1061     3.0  1061      용현5동     4.0
# 3       3.0     2024.0  그리드2728     4.0  2728      주안1동     5.0
# 4       4.0      526.0   그리드941     5.0   941      용현5동    11.0
# ..      ...        ...      ...     ...   ...       ...     ...
# 95      NaN     2560.0  그리드3503    94.0  3503       NaN     NaN
# 96      NaN      513.0   그리드928    95.0   928       NaN     NaN
# 97      NaN      264.0   그리드575    97.0   575       NaN     NaN
# 98      NaN     2057.0  그리드2772    98.0  2772       NaN     NaN
# 99      NaN     1479.0  그리드2080    99.0  2080       NaN     NaN
#
# [100 rows x 7 columns]

# %%
a = pb['fid']

# %%
a
# Out:
# 0     3211
# 1     2783
# 2     1061
# 3     2728
# 4      941
#       ...
# 95    3503
# 96     928
# 97     575
# 98    2772
# 99    2080
# Name: fid, Length: 100, dtype: int64

# %%
ich_bf = ich[ich['grid'].isin(a)]

# %%
ich = pd.read_csv("C:/Users/keogu/Desktop/IGPS/Data/인천시_대여소정보.csv", encoding = 'cp949')

# %%
ich
# Out:
#       grid  rank  미추홀구_데이터종합_교육시설_sum  미추홀구_데이터종합_근린생활시설_sum  \
# 0     3211     1                 0.00              6398.2700
# 1     2783     2                 0.00             34650.8265
# 2     2724     3                 0.00             14927.6500
# 3     1061     4                 0.00             51159.2200
# 4     2728     5                 0.00             14331.5700
# ...    ...   ...                  ...                    ...
# 2647  3098  2648              2407.20              2466.3800
# 2648  3115  2649             12943.79                 0.0000
# 2649  3586  2650                 0.00                 0.0000
# 2650  3525  2651                 0.00                 0.0000
# 2651  3649  2652             16123.39                 0.0000
#
#       미추홀구_데이터종합_문화시설_sum  미추홀구_데이터종합_숙박시설_sum  미추홀구_데이터종합_업무시설_sum  \
# 0              7994075.00                  0.0               0.0000
# 1                 4841.13                  0.0               0.0000
# 2                 8393.52                  0.0             990.6000
# 3                    0.00                  0.0           87634.3188
# 4                 1690.85                  0.0           11332.1100
# ...                   ...                  ...                  ...
# 2647                 0.00                  0.0               0.0000
# 2648                 0.00                  0.0               0.0000
# 2649                 0.00                  0.0               0.0000
# 2650                 0.00                  0.0               0.0000
# 2651                 0.00                  0.0               0.0000
#
#       미추홀구_데이터종합_의료시설_sum  미추홀구_데이터종합_주거시설_sum  미추홀구_데이터종합_판매시설_sum  \
# 0                   0.000              681.770                  0.0
# 1                   0.000                0.000              33578.9
# 2                   0.000             1858.980              33578.9
# 3                   0.000                0.000                  0.0
# 4                   0.000                0.000                  0.0
# ...                   ...                  ...                  ...
# 2647            13265.415             4059.179                  0.0
# 2648                0.000              587.210                  0.0
# 2649                0.000            57897.340                  0.0
# 2650                0.000            61825.810                  0.0
# 2651                0.000            25754.630                  0.0
#
#       미추홀구_데이터종합_공원_distance  미추홀구_데이터종합_대학교_distance  \
# 0                 414.350416              2042.522003
# 1                 418.005942              1000.365546
# 2                 302.970723              1057.394493
# 3                 623.304372               461.616796
# 4                 492.159492              1443.647732
# ...                      ...                      ...
# 2647              227.525770              2577.619939
# 2648               53.243772              2993.882214
# 2649              221.413224              3460.695385
# 2650              218.115457              3346.933911
# 2651              364.805998              3618.494783
#
#       미추홀구_데이터종합_지하철_distance  미추홀구_데이터종합_버스_distance  미추홀구_데이터종합_경사도_mean  \
# 0                  295.293579               43.297457                  1.5
# 1                  145.981155               27.296763                  2.0
# 2                  237.953719               41.047116                  2.0
# 3                  127.875858              130.520513                  0.5
# 4                   66.600216               22.627794                  1.0
# ...                       ...                     ...                  ...
# 2647               939.433839               57.633144                  1.5
# 2648              1352.499623              255.513536                  4.5
# 2649               345.964117              130.864959                  0.5
# 2650               480.335337              110.914349                  1.0
# 2651               271.149021               91.185408                  0.5
#
#       미추홀구_데이터종합_거주인구  미추홀구_데이터종합_도로길이
# 0                5436       167.433246
# 1               12132       200.089197
# 2               12132       200.178224
# 3               23824        86.278613
# 4               12132       151.149628
# ...               ...              ...
# 2647             9503       259.614351
# 2648             7239        34.084735
# 2649             6826         0.000000
# 2650             6826         0.000000
# 2651             6826         0.000000
#
# [2652 rows x 17 columns]

# %%
ich = ich[ich['rank'] < 100]

# %%
ich.drop(columns=['grid'], inplace=True)

# %%
ich_bf.drop(columns=['grid'], inplace=True)

# %%
ich.set_index(['rank'], inplace=True)

# %%
ich_bf.set_index(['rank'], inplace=True)

# %%
ich_bf
# Out:
#       미추홀구_데이터종합_교육시설_sum  미추홀구_데이터종합_근린생활시설_sum  미추홀구_데이터종합_문화시설_sum  \
# rank
# 1                     0.0              6398.2700           7994075.00
# 2                     0.0             34650.8265              4841.13
# 3                     0.0             14927.6500              8393.52
# 4                     0.0             51159.2200                 0.00
# 5                     0.0             14331.5700              1690.85
# ...                   ...                    ...                  ...
# 96                    0.0              7152.0850                 0.00
# 97                    0.0              2688.5350                 0.00
# 98                    0.0               355.7000                 0.00
# 99                    0.0              5796.0800                 0.00
# 100                   0.0              1652.0200                 0.00
#
#       미추홀구_데이터종합_숙박시설_sum  미추홀구_데이터종합_업무시설_sum  미추홀구_데이터종합_의료시설_sum  \
# rank
# 1                    0.00               0.0000                  0.0
# 2                    0.00               0.0000                  0.0
# 3                    0.00             990.6000                  0.0
# 4                    0.00           87634.3188                  0.0
# 5                    0.00           11332.1100                  0.0
# ...                   ...                  ...                  ...
# 96                   0.00            1302.7200                  0.0
# 97                   0.00            1475.0400                  0.0
# 98                   0.00            7622.5900                  0.0
# 99                   0.00            3099.0400                  0.0
# 100                909.65           50489.7200                  0.0
#
#       미추홀구_데이터종합_주거시설_sum  미추홀구_데이터종합_판매시설_sum  미추홀구_데이터종합_공원_distance  \
# rank
# 1                 681.770                 0.00              414.350416
# 2                   0.000             33578.90              418.005942
# 3                1858.980             33578.90              302.970723
# 4                   0.000                 0.00              623.304372
# 5                   0.000                 0.00              492.159492
# ...                   ...                  ...                     ...
# 96               6323.550                 0.00              703.540999
# 97               5030.420              2388.00              458.452741
# 98                  0.000                 0.00              876.895673
# 99               1612.580              1991.13              497.401064
# 100             26752.125                 0.00              793.003898
#
#       미추홀구_데이터종합_대학교_distance  미추홀구_데이터종합_지하철_distance  \
# rank
# 1                 2042.522003               295.293579
# 2                 1000.365546               145.981155
# 3                 1057.394493               237.953719
# 4                  461.616796               127.875858
# 5                 1443.647732                66.600216
# ...                       ...                      ...
# 96                 332.959793               653.632286
# 97                 766.519198              1379.393073
# 98                1955.098518               215.493085
# 99                1111.543819               433.930054
# 100               1749.617644               259.746265
#
#       미추홀구_데이터종합_버스_distance  미추홀구_데이터종합_경사도_mean  미추홀구_데이터종합_거주인구  \
# rank
# 1                  43.297457                  1.5             5436
# 2                  27.296763                  2.0            12132
# 3                  41.047116                  2.0            12132
# 4                 130.520513                  0.5            23824
# 5                  22.627794                  1.0            12132
# ...                      ...                  ...              ...
# 96                 81.919628                  2.5             8420
# 97                 54.750773                  1.5            23076
# 98                 47.361179                  0.0             7044
# 99                 79.275077                  0.5            11093
# 100                86.817933                  1.0             7044
#
#       미추홀구_데이터종합_도로길이
# rank
# 1          167.433246
# 2          200.089197
# 3          200.178224
# 4           86.278613
# 5          151.149628
# ...               ...
# 96         350.432870
# 97         410.403891
# 98           0.000000
# 99         165.640545
# 100        288.065692
#
# [100 rows x 15 columns]

# %%
# 분포확인
plt.figure(figsize=(16,24)) 
n=1
for feature in ich.columns:
    ax = plt.subplot(4,4,n) 
    plt.title('%s의 분포' %feature, fontsize=15)
    sns.distplot(ich[feature], kde =False)
    plt.xticks(rotation=90)
    n+=1
plt.tight_layout() 
plt.show()

# %%
# 왜도 확인
from scipy.stats import skew

features_index = ich.dtypes[ich.dtypes != 'object'].index
skew_features = ich[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features > 1]
print(skew_features_top.sort_values(ascending=False))
# Out:
# 미추홀구_데이터종합_의료시설_sum        9.798480
# 미추홀구_데이터종합_문화시설_sum        9.798435
# 미추홀구_데이터종합_숙박시설_sum        5.390999
# 미추홀구_데이터종합_판매시설_sum        4.159692
# 미추홀구_데이터종합_근린생활시설_sum      3.079808
# 미추홀구_데이터종합_주거시설_sum        2.354132
# 미추홀구_데이터종합_업무시설_sum        2.215878
# 미추홀구_데이터종합_지하철_distance    1.474642
# 미추홀구_데이터종합_대학교_distance    1.255853
# 미추홀구_데이터종합_버스_distance     1.103552
# dtype: float64

# %%
# 왜도 확인
from scipy.stats import skew

features_index = ich_bf.dtypes[ich_bf.dtypes != 'object'].index
skew_features = ich_bf[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features > 1]
print(skew_features_top.sort_values(ascending=False))
# Out:
# 미추홀구_데이터종합_의료시설_sum        9.849371
# 미추홀구_데이터종합_문화시설_sum        9.849326
# 미추홀구_데이터종합_숙박시설_sum        5.359356
# 미추홀구_데이터종합_판매시설_sum        4.183687
# 미추홀구_데이터종합_근린생활시설_sum      3.093245
# 미추홀구_데이터종합_주거시설_sum        2.555301
# 미추홀구_데이터종합_업무시설_sum        2.186702
# 미추홀구_데이터종합_지하철_distance    1.490206
# 미추홀구_데이터종합_대학교_distance    1.240325
# 미추홀구_데이터종합_버스_distance     1.104758
# dtype: float64

# %%
# 복사
ich_log = ich.copy()

# %%
# 복사
ich_log_bf = ich_bf.copy()

# %%
# log변환
ich_log[skew_features_top.index] = np.log1p(ich[skew_features_top.index])
ich_log
# Out:
#       미추홀구_데이터종합_교육시설_sum  미추홀구_데이터종합_근린생활시설_sum  미추홀구_데이터종합_문화시설_sum  \
# rank
# 1                     0.0               8.763939            15.894211
# 2                     0.0              10.453106             8.485110
# 3                     0.0               9.611037             9.035334
# 4                     0.0              10.842718             0.000000
# 5                     0.0               9.570290             7.433578
# ...                   ...                    ...                  ...
# 95                    0.0               8.989987             0.000000
# 96                    0.0               8.875299             0.000000
# 97                    0.0               7.897124             0.000000
# 98                    0.0               5.876895             0.000000
# 99                    0.0               8.665110             0.000000
#
#       미추홀구_데이터종합_숙박시설_sum  미추홀구_데이터종합_업무시설_sum  미추홀구_데이터종합_의료시설_sum  \
# rank
# 1                     0.0             0.000000                  0.0
# 2                     0.0             0.000000                  0.0
# 3                     0.0             6.899320                  0.0
# 4                     0.0            11.380939                  0.0
# 5                     0.0             9.335484                  0.0
# ...                   ...                  ...                  ...
# 95                    0.0             0.000000                  0.0
# 96                    0.0             7.172977                  0.0
# 97                    0.0             7.297118                  0.0
# 98                    0.0             8.939003                  0.0
# 99                    0.0             8.039170                  0.0
#
#       미추홀구_데이터종합_주거시설_sum  미추홀구_데이터종합_판매시설_sum  미추홀구_데이터종합_공원_distance  \
# rank
# 1                6.526158             0.000000              414.350416
# 2                0.000000            10.421683              418.005942
# 3                7.528321            10.421683              302.970723
# 4                0.000000             0.000000              623.304372
# 5                0.000000             0.000000              492.159492
# ...                   ...                  ...                     ...
# 95               5.307723             0.000000              574.306012
# 96               8.752194             0.000000              703.540999
# 97               8.523458             7.778630              458.452741
# 98               0.000000             0.000000              876.895673
# 99               7.386211             7.596960              497.401064
#
#       미추홀구_데이터종합_대학교_distance  미추홀구_데이터종합_지하철_distance  \
# rank
# 1                    7.622430                 5.691351
# 2                    6.909120                 4.990304
# 3                    6.964508                 5.476270
# 4                    6.136899                 4.858850
# 5                    7.275621                 4.213611
# ...                       ...                      ...
# 95                   7.341035                 3.653215
# 96                   5.811021                 6.484074
# 97                   6.643163                 7.230124
# 98                   7.578707                 5.377559
# 99                   7.014404                 6.075185
#
#       미추홀구_데이터종합_버스_distance  미추홀구_데이터종합_경사도_mean  미추홀구_데이터종합_거주인구  \
# rank
# 1                   3.790927                  1.5             5436
# 2                   3.342747                  2.0            12132
# 3                   3.738791                  2.0            12132
# 4                   4.879163                  0.5            23824
# 5                   3.162424                  1.0            12132
# ...                      ...                  ...              ...
# 95                  4.377056                  1.5            24663
# 96                  4.417872                  2.5             8420
# 97                  4.020891                  1.5            23076
# 98                  3.878697                  0.0             7044
# 99                  4.385459                  0.5            11093
#
#       미추홀구_데이터종합_도로길이
# rank
# 1          167.433246
# 2          200.089197
# 3          200.178224
# 4           86.278613
# 5          151.149628
# ...               ...
# 95         200.394787
# 96         350.432870
# 97         410.403891
# 98           0.000000
# 99         165.640545
#
# [99 rows x 15 columns]

# %%
# log변환
ich_log_bf[skew_features_top.index] = np.log1p(ich_bf[skew_features_top.index])
ich_log_bf
# Out:
#       미추홀구_데이터종합_교육시설_sum  미추홀구_데이터종합_근린생활시설_sum  미추홀구_데이터종합_문화시설_sum  \
# rank
# 1                     0.0               8.763939            15.894211
# 2                     0.0              10.453106             8.485110
# 3                     0.0               9.611037             9.035334
# 4                     0.0              10.842718             0.000000
# 5                     0.0               9.570290             7.433578
# ...                   ...                    ...                  ...
# 96                    0.0               8.875299             0.000000
# 97                    0.0               7.897124             0.000000
# 98                    0.0               5.876895             0.000000
# 99                    0.0               8.665110             0.000000
# 100                   0.0               7.410359             0.000000
#
#       미추홀구_데이터종합_숙박시설_sum  미추홀구_데이터종합_업무시설_sum  미추홀구_데이터종합_의료시설_sum  \
# rank
# 1                0.000000             0.000000                  0.0
# 2                0.000000             0.000000                  0.0
# 3                0.000000             6.899320                  0.0
# 4                0.000000            11.380939                  0.0
# 5                0.000000             9.335484                  0.0
# ...                   ...                  ...                  ...
# 96               0.000000             7.172977                  0.0
# 97               0.000000             7.297118                  0.0
# 98               0.000000             8.939003                  0.0
# 99               0.000000             8.039170                  0.0
# 100              6.814159            10.829545                  0.0
#
#       미추홀구_데이터종합_주거시설_sum  미추홀구_데이터종합_판매시설_sum  미추홀구_데이터종합_공원_distance  \
# rank
# 1                6.526158             0.000000              414.350416
# 2                0.000000            10.421683              418.005942
# 3                7.528321            10.421683              302.970723
# 4                0.000000             0.000000              623.304372
# 5                0.000000             0.000000              492.159492
# ...                   ...                  ...                     ...
# 96               8.752194             0.000000              703.540999
# 97               8.523458             7.778630              458.452741
# 98               0.000000             0.000000              876.895673
# 99               7.386211             7.596960              497.401064
# 100             10.194407             0.000000              793.003898
#
#       미추홀구_데이터종합_대학교_distance  미추홀구_데이터종합_지하철_distance  \
# rank
# 1                    7.622430                 5.691351
# 2                    6.909120                 4.990304
# 3                    6.964508                 5.476270
# 4                    6.136899                 4.858850
# 5                    7.275621                 4.213611
# ...                       ...                      ...
# 96                   5.811021                 6.484074
# 97                   6.643163                 7.230124
# 98                   7.578707                 5.377559
# 99                   7.014404                 6.075185
# 100                  7.467724                 5.563548
#
#       미추홀구_데이터종합_버스_distance  미추홀구_데이터종합_경사도_mean  미추홀구_데이터종합_거주인구  \
# rank
# 1                   3.790927                  1.5             5436
# 2                   3.342747                  2.0            12132
# 3                   3.738791                  2.0            12132
# 4                   4.879163                  0.5            23824
# 5                   3.162424                  1.0            12132
# ...                      ...                  ...              ...
# 96                  4.417872                  2.5             8420
# 97                  4.020891                  1.5            23076
# 98                  3.878697                  0.0             7044
# 99                  4.385459                  0.5            11093
# 100                 4.475266                  1.0             7044
#
#       미추홀구_데이터종합_도로길이
# rank
# 1          167.433246
# 2          200.089197
# 3          200.178224
# 4           86.278613
# 5          151.149628
# ...               ...
# 96         350.432870
# 97         410.403891
# 98           0.000000
# 99         165.640545
# 100        288.065692
#
# [100 rows x 15 columns]

# %% [markdown]
# # 서울시 데이터

# %%
total = pd.read_csv("C:/Users/keogu/Desktop/IGPS/Data/서울시_데이터종합_수정.csv")

# %%
total
# Out:
#        대여소번호  교육시설_sum  근린생활시설_sum  문화시설_sum  숙박시설_sum  업무시설_sum  의료시설_sum  \
# 0      502.0      0.00        0.00      0.00       0.0    906.60       0.0
# 1      207.0      0.00      161.73      0.00       0.0      0.00       0.0
# 2     3533.0      0.00     5763.49   4697.48       0.0      0.00       0.0
# 3     1210.0      0.00        0.00      0.00       0.0      0.00       0.0
# 4     1308.0  39658.62    27219.63    552.09       0.0   3227.37       0.0
# ...      ...       ...         ...       ...       ...       ...       ...
# 1477   664.0  61560.86        0.00   7622.29       0.0      0.00       0.0
# 1478  2287.0      0.00     3830.38      0.00       0.0      0.00       0.0
# 1479  2391.0      0.00        0.00      0.00       0.0      0.00       0.0
# 1480   465.0      0.00     6864.08      0.00       0.0      0.00       0.0
# 1481  3543.0  73957.07        0.00   4825.13       0.0      0.00       0.0
#
#        주거시설_sum  판매시설_sum  공원_distance  대학교_distance  지하철_distance  \
# 0     137575.50      0.00   137.510195   1430.131460     55.873032
# 1      62279.03      0.00   209.972349   2254.225628     72.001620
# 2       1152.39  90429.46   161.743567    639.201940    175.855911
# 3          0.00      0.00   324.671476   2761.514679    145.087355
# 4       8097.88      0.00   332.366534    749.646476    408.450803
# ...         ...       ...          ...           ...           ...
# 1477       0.00      0.00   332.212513     88.481654    592.515746
# 1478    4749.01      0.00   187.100314   5396.477786   3469.661173
# 1479    3456.00      0.00   366.727904   4119.802431   1206.457463
# 1480     527.37      0.00   377.608155    301.960064   1245.792726
# 1481    3332.92      0.00   361.589287     69.821617    373.301440
#
#       버스_distance  경사도_mean   거주인구         도로길이   일별대여평균이용량
# 0       59.208388  0.500000  24085   714.440640  258.605479
# 1       31.257419  1.000000  15710   356.416445  250.934247
# 2       42.881442  0.000000  43626   549.726995  135.227397
# 3       70.406036  0.333333  24052   348.694407  133.017808
# 4       12.103377  1.250000  41364  1258.678353  117.180822
# ...           ...       ...    ...          ...         ...
# 1477   370.864704  2.000000   8727     0.000000    7.950860
# 1478   272.330166  7.444444   8164   749.655227    0.664384
# 1479   144.812218  4.500000  14769   345.607938    0.583562
# 1480   167.833245  6.250000   1224   424.978106    3.122850
# 1481   209.554916  1.000000  12977   127.856886    7.616798
#
# [1482 rows x 17 columns]

# %%
total.set_index(['대여소번호'], inplace=True)

# %%
# 왜도 확인
from scipy.stats import skew

features_index = total.dtypes[total.dtypes != 'object'].index
skew_features = total[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features > 1]
print(skew_features_top.sort_values(ascending=False))
# Out:
# 문화시설_sum        17.913397
# 숙박시설_sum        11.841145
# 의료시설_sum        10.670393
# 판매시설_sum         9.106897
# 근린생활시설_sum       8.937168
# 주거시설_sum         7.143945
# 교육시설_sum         4.636081
# 업무시설_sum         4.076714
# 지하철_distance     2.959794
# 일별대여평균이용량        2.951318
# 공원_distance      2.918526
# 버스_distance      2.488875
# 경사도_mean         1.710297
# dtype: float64

# %%
# 복사
total_log = total.copy()

# %%
# log변환
total_log[skew_features_top.index] = np.log1p(total[skew_features_top.index])
total_log
# Out:
#          교육시설_sum  근린생활시설_sum  문화시설_sum  숙박시설_sum  업무시설_sum  의료시설_sum  \
# 대여소번호
# 502.0    0.000000    0.000000  0.000000       0.0  6.810804       0.0
# 207.0    0.000000    5.092092  0.000000       0.0  0.000000       0.0
# 3533.0   0.000000    8.659472  8.454994       0.0  0.000000       0.0
# 1210.0   0.000000    0.000000  0.000000       0.0  0.000000       0.0
# 1308.0  10.588089   10.211730  6.315521       0.0  8.079733       0.0
# ...           ...         ...       ...       ...       ...       ...
# 664.0   11.027798    0.000000  8.938963       0.0  0.000000       0.0
# 2287.0   0.000000    8.250980  0.000000       0.0  0.000000       0.0
# 2391.0   0.000000    0.000000  0.000000       0.0  0.000000       0.0
# 465.0    0.000000    8.834203  0.000000       0.0  0.000000       0.0
# 3543.0  11.211254    0.000000  8.481800       0.0  0.000000       0.0
#
#          주거시설_sum   판매시설_sum  공원_distance  대학교_distance  지하철_distance  \
# 대여소번호
# 502.0   11.831935   0.000000     4.930944   1430.131460      4.040821
# 207.0   11.039396   0.000000     5.351727   2254.225628      4.290482
# 3533.0   7.050461  11.412336     5.092176    639.201940      5.175335
# 1210.0   0.000000   0.000000     5.785889   2761.514679      4.984205
# 1308.0   8.999481   0.000000     5.809243    749.646476      6.014817
# ...           ...        ...          ...           ...           ...
# 664.0    0.000000   0.000000     5.808780     88.481654      6.386064
# 2287.0   8.465902   0.000000     5.236975   5396.477786      8.152100
# 2391.0   8.148156   0.000000     5.907343   4119.802431      7.096272
# 465.0    6.269797   0.000000     5.936502    301.960064      7.128330
# 3543.0   8.111904   0.000000     5.893271     69.821617      5.925061
#
#         버스_distance  경사도_mean   거주인구         도로길이  일별대여평균이용량
# 대여소번호
# 502.0      4.097812  0.405465  24085   714.440640   5.559163
# 207.0      3.473748  0.693147  15710   356.416445   5.529168
# 3533.0     3.781491  0.000000  43626   549.726995   4.914326
# 1210.0     4.268382  0.287682  24052   348.694407   4.897973
# 1308.0     2.572870  0.810930  41364  1258.678353   4.772216
# ...             ...       ...    ...          ...        ...
# 664.0      5.918530  1.098612   8727     0.000000   2.191750
# 2287.0     5.610680  2.133509   8164   749.655227   0.509455
# 2391.0     4.982320  1.704748  14769   345.607938   0.459677
# 465.0      5.128912  1.981001   1224   424.978106   1.416545
# 3543.0     5.349747  0.693147  12977   127.856886   2.153714
#
# [1482 rows x 16 columns]

# %% [markdown]
# # 회귀분석

# %%
y_train = total_log['일별대여평균이용량']
X_train = total_log.drop('일별대여평균이용량', axis=1, inplace=False)

# %%
X_test = ich_log_bf

# %%
y_train_scaled = y_train.copy()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

#원래 값을 구하기 위해?
scaler_train = MinMaxScaler()
X_train_scaled = scaler_train.fit_transform(X_train)

scaler_test = MinMaxScaler()
X_test_scaled = scaler_test.fit_transform(X_test)

scaler_y = MinMaxScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train_scaled, y_train_scaled)
pred_lr = lr.predict(X_test_scaled)

# %%
pred_lr= scaler_y.inverse_transform(np.array(pred_lr).reshape(-1,1))
pred_lr = np.expm1(pred_lr)

# %%
pred_lr
# Out:
# array([[14.26689425],
#        [17.92886983],
#        [19.85560055],
#        [42.94517811],
#        [27.74586806],
#        [45.42859587],
#        [55.78438708],
#        [15.83020354],
#        [46.01540351],
#        [18.92015382],
#        [43.70953459],
#        [43.81959527],
#        [16.57557842],
#        [51.73544228],
#        [28.17456789],
#        [41.13089092],
#        [16.74834131],
#        [25.59261816],
#        [29.07966738],
#        [21.05483963],
#        [12.89594126],
#        [24.82897375],
#        [39.50176766],
#        [36.55641956],
#        [25.42002462],
#        [27.34122214],
#        [37.30582143],
#        [20.64210997],
#        [21.66155925],
#        [45.85036234],
#        [19.70875207],
#        [20.17014959],
#        [30.19866969],
#        [28.6558828 ],
#        [18.35750133],
#        [25.83025282],
#        [18.25223046],
#        [15.26753116],
#        [18.62771065],
#        [22.59423091],
#        [18.0349972 ],
#        [15.92355301],
#        [16.42766778],
#        [25.11426974],
#        [37.25441333],
#        [19.76194583],
#        [27.79564083],
#        [15.29208115],
#        [36.02934174],
#        [17.49421993],
#        [ 8.82259047],
#        [13.78597984],
#        [10.10484191],
#        [18.25511778],
#        [15.17668286],
#        [11.56817977],
#        [18.22711334],
#        [12.22436761],
#        [22.21606082],
#        [16.6998458 ],
#        [20.59886228],
#        [17.70010451],
#        [18.19412968],
#        [32.09420602],
#        [30.8026243 ],
#        [13.97799339],
#        [21.57806415],
#        [18.05885976],
#        [ 8.82515339],
#        [24.53116867],
#        [23.39894448],
#        [ 9.68208764],
#        [15.71401438],
#        [21.3510194 ],
#        [13.6407173 ],
#        [23.40303506],
#        [14.81768584],
#        [17.67676832],
#        [ 8.08032742],
#        [40.0848541 ],
#        [ 9.67605513],
#        [19.49822956],
#        [41.5242812 ],
#        [30.75812111],
#        [20.58616455],
#        [16.67783974],
#        [23.14694409],
#        [18.19133392],
#        [ 6.26362753],
#        [33.28661601],
#        [ 9.22341889],
#        [24.48433368],
#        [11.74745077],
#        [12.46997847],
#        [22.53693175],
#        [16.43712876],
#        [23.51541934],
#        [24.47884229],
#        [28.11101831],
#        [21.38510192]])

# %%
sum(pred_lr)
# Out:
# array([2316.42771182])

# %%
len(pred_lr)
# Out:
# 100

# %%
plt.figure(figsize=(20,10))
plt.plot(pred_lr, 'r', label='lr')
plt.legend()
plt.show()
